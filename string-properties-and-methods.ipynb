# %%
name = 'Sam'

# %%
# name[0] = 'P'

# %%
name = 'P' + name[1:]

# %%
name
# Out:
# 'Pam'

# %%
x = 'Hello World'

# %%
x = x + " it is beautiful outisde!"

# %%
x
# Out:
# 'Hello World it is beautiful outisde! it is beautiful outisde!'

# %%
letter = 'z'

# %%
letter * 10
# Out:
# 'zzzzzzzzzz'

# %%
2 + 3
# Out:
# 5

# %%
'2' + '3'
# Out:
# '23'

# %%
# 2 + '3' does not work

# %%
x = 'hello world'

# %%
x.upper()
# Out:
# 'HELLO WORLD'

# %%
x
# Out:
# 'hello world'
